# %% [markdown]
# <a href="https://colab.research.google.com/github/biubiugun/machine-learing/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels) = fashion_mnist.load_data()
train_images = train_images / 255.0
test_images = test_images / 255.0

# %%
#多层感知机
model = keras.Sequential([
        keras.layers.Flatten(input_shape=(28,28)),
        keras.layers.Dense(256,activation='relu'),
        keras.layers.Dense(32,activation='relu'),
        keras.layers.Dense(10,activation=None)
])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0007),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4983 - accuracy: 0.8254
# Epoch 2/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3663 - accuracy: 0.8663
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3319 - accuracy: 0.8790
# Epoch 4/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3073 - accuracy: 0.8874
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2876 - accuracy: 0.8936
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2740 - accuracy: 0.8982
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2606 - accuracy: 0.9014
# Epoch 8/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2483 - accuracy: 0.9076
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2392 - accuracy: 0.9109
# Epoch 10/10
# ...

# %%
#单层感知机
model = keras.Sequential([
        keras.layers.Flatten(input_shape=(28,28)),
        keras.layers.Dense(
            units = 10,
            activation = None,
            kernel_initializer=tf.zeros_initializer(),
            bias_initializer=tf.zeros_initializer()
        )
])
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.0058),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=15)
# Out:
# Epoch 1/13
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.9259 - accuracy: 0.7234
# Epoch 2/13
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6485 - accuracy: 0.7941
# Epoch 3/13
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5878 - accuracy: 0.8111
# Epoch 4/13
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5550 - accuracy: 0.8197
# Epoch 5/13
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5337 - accuracy: 0.8249
# Epoch 6/13
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.5181 - accuracy: 0.8293
# Epoch 7/13
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.5061 - accuracy: 0.8329
# Epoch 8/13
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4962 - accuracy: 0.8356
# Epoch 9/13
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4886 - accuracy: 0.8374
# Epoch 10/13
# ...

# %% [markdown]
# # 新段落

# %%
test_loss,test_accuracy = model.evaluate(test_images,test_labels,verbose=2)
print('\nTest accuracy=',test_accuracy)
# Out:
# 313/313 - 0s - loss: 0.4992 - accuracy: 0.8294
#
# Test accuracy= 0.8294000029563904
